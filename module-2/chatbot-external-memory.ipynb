# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/chatbot-external-memory.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239440-lesson-6-chatbot-w-summarizing-messages-and-external-memory)

# %% [markdown]
# # Chatbot with message summarization & external DB memory
#
# ## Review
#
# We've covered how to customize graph state schema and reducer.
#
# We've also shown a number of tricks for trimming or filtering messages in graph state.
#
# We've used these concepts in a Chatbot with memory that produces a running summary of the conversation.
#
# ## Goals
#
# But, what if we want our Chatbot to have memory that persists indefinitely?
#
# Now, we'll introduce some more advanced checkpointers that support external databases.
#
# Here, we'll show how to use [Sqlite as a checkpointer](https://langchain-ai.github.io/langgraph/concepts/low_level/#checkpointer), but other checkpointers, such as [Postgres](https://langchain-ai.github.io/langgraph/how-tos/persistence_postgres/) are available!

# %%
import os
from dotenv import load_dotenv, find_dotenv

langsmith_key = os.getenv("LANGSMITH_API_KEY")
_ = load_dotenv(find_dotenv())

# login LANGSMITH
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langchain-academy"

# %% [markdown]
# ## Sqlite
#
# A good starting point here is the [SqliteSaver checkpointer](https://langchain-ai.github.io/langgraph/concepts/low_level/#checkpointer).
#
# Sqlite is a [small, fast, highly popular](https://x.com/karpathy/status/1819490455664685297) SQL database.
#
# If we supply `":memory:"` it creates an in-memory Sqlite database.

# %%
import sqlite3
# In memory
conn = sqlite3.connect(":memory:", check_same_thread = False)

# %% [markdown]
# But, if we supply a db path, then it will create a database for us!

# %%
# pull file if it doesn't exist and connect to local db
# !mkdir -p state_db && [ ! -f state_db/example.db ] && wget -P state_db https://github.com/langchain-ai/langchain-academy/raw/main/module-2/state_db/example.db

db_path = "state_db/example.db"
conn = sqlite3.connect(db_path, check_same_thread=False)
# Out:
# --2025-10-07 13:48:48--  https://github.com/langchain-ai/langchain-academy/raw/main/module-2/state_db/example.db
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/langchain-ai/langchain-academy/main/module-2/state_db/example.db [following]
# --2025-10-07 13:48:48--  https://raw.githubusercontent.com/langchain-ai/langchain-academy/main/module-2/state_db/example.db
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 110592 (108K) [application/octet-stream]
# Saving to: ‘state_db/example.db’
#
# example.db          100%[===================>] 108.00K  --.-KB/s    in 0.04s
#
# 2025-10-07 13:48:49 (2.36 MB/s) - ‘state_db/example.db’ saved [110592/110592]

# %%
# Here is our checkpointer 
from langgraph.checkpoint.sqlite import SqliteSaver
memory = SqliteSaver(conn)

# %% [markdown]
# Let's re-define our chatbot.

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage

from langgraph.graph import END
from langgraph.graph import MessagesState

model = ChatOllama(model="gpt-oss:20b-cloud",temperature=0)

class State(MessagesState):
    summary: str

# Define the logic to call the model
def call_model(state: State):
    
    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:
        
        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]
    
    else:
        messages = state["messages"]
    
    response = model.invoke(messages)
    return {"messages": response}

def summarize_conversation(state: State):
    
    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt 
    if summary:
        
        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
        
    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)
    
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# Determine whether to end or summarize the conversation
def should_continue(state: State):
    
    """Return the next node to execute."""
    
    messages = state["messages"]
    
    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"
    
    # Otherwise we can just end
    return END

# %% [markdown]
# Now, we just re-compile with our sqlite checkpointer.

# %%
from IPython.display import Image, display
from langgraph.graph import StateGraph, START

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# Now, we can invoke the graph several times.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Emmanuel")
output = graph.invoke({"messages": [input_message]}, config) 
for m in output['messages'][-1:]:
    m.pretty_print()

input_message = HumanMessage(content="what's my name?")
output = graph.invoke({"messages": [input_message]}, config) 
for m in output['messages'][-1:]:
    m.pretty_print()

input_message = HumanMessage(content="i like Chelsea Football Club!")
output = graph.invoke({"messages": [input_message]}, config) 
for m in output['messages'][-1:]:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hello Emmanuel! Nice to meet you. How can I help you today? If you’d like to keep talking about the 49ers or anything else, just let me know!
# ================================== Ai Message ==================================
#
# You’re Emmanuel.
# ================================== Ai Message ==================================
#
# That’s great! Chelsea has had some exciting seasons over the years. Do you have a favorite player or a particular match that stands out for you?

# %% [markdown]
# Let's confirm that our state is saved locally.

# %%
config = {"configurable": {"thread_id": "1"}}
graph_state = graph.get_state(config)
graph_state
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content="hi! I'm Emmanuel", additional_kwargs={}, response_metadata={}, id='dbddbbf8-2ec7-4334-86f7-d3ee7cf83735'), AIMessage(content='Hello Emmanuel! Nice to meet you. How can I help you today? If you’d like to keep talking about the 49ers or anything else, just let me know!', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b-cloud', 'created_at': '2025-10-07T19:02:07.604773746Z', 'done': True, 'done_reason': 'stop', 'total_duration': 905316289, 'load_duration': None, 'prompt_eval_count': 392, 'prompt_eval_duration': None, 'eval_count': 123, 'eval_duration': None, 'model_name': 'gpt-oss:20b-cloud'}, id='run--3652cad5-f65f-43d3-90cc-505f10b6cb5b-0', usage_metadata={'input_tokens': 392, 'output_tokens': 123, 'total_tokens': 515}), HumanMessage(content="what's my name?", additional_kwargs={}, response_metadata={}, id='0dab5b81-c82c-4cc0-a1e9-7b962c5f093d'), AIMessage(content='You’re Emmanuel.', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b-cloud', 'created_at': '2025-10-07T19:02:10.195240624Z', 'done': True, 'done_reason': 'stop', 'total_duration': 846100970, 'load_duration': None, 'prompt_eval_count': 338, 'prompt_eval_duration': None, 'eval_count': 71, 'eval_duration': None, 'model_name': 'gpt-oss:20b-cloud'}, id='run--ef9aa052-c59d-4cf3-90d8-2bf7f08f29a1-0', usage_metadata={'input_tokens': 338, 'output_tokens': 71, 'total_tokens': 409}), HumanMessage(content='i like Chelsea Football Club!', additional_kwargs={}, response_metadata={}, id='0b8b7106-20b7-462c-99ce-e37d68a0e7ca'), AIMessage(content='That’s great! Chelsea has had some exciting seasons over the years. Do you have a favorite player or a particular match that stands out for you?', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b-cloud', 'created_at': '2025-10-07T19:02:11.032407832Z', 'done': True, 'done_reason': 'stop', 'total_duration': 641049720, 'load_duration': None, 'prompt_eval_count': 358, 'prompt_eval_duration': None, 'eval_count': 100, 'eval_duration': None, 'model_name': 'gpt-oss:20b-cloud'}, id='run--d9e25eb2-be71-4931-8725-fdebf0f9beec-0', usage_metadata={'input_tokens': 358, 'output_tokens': 100, 'total_tokens': 458})], 'summary': '**Extended Summary of the Conversation**\n\n1. **Initial Interaction**  \n   - The user first introduced themselves as **Lance** and expressed a fondness for the San\u202fFrancisco\u202f49ers.  \n   - The assistant acknowledged Lance’s name and offered to discuss various aspects of the 49ers (history, roster, memorable games, etc.).  \n   - Lance repeated his introduction, and the assistant reiterated his name and readiness to talk about the team.\n\n2. **Repetition and Briefness**  \n   - The conversation remained brief and somewhat repetitive, with Lance re‑introducing himself at the end without directly responding to the assistant’s prompts about the 49ers.\n\n3. **Name Change**  \n   - In a subsequent message, the user introduced themselves as **Emmanuel**.  \n   - The assistant greeted Emmanuel and asked how it could help, offering to continue discussing the 49ers or any other topic.\n\nThe conversation now reflects a change in the user’s name from Lance to Emmanuel, with the assistant acknowledging the new name and remaining open to further discussion.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0a3b02-0e96-6f96-801b-2b9cf3d0c538'}}, metadata={'source': 'loop', 'step': 27, 'parents': {}}, created_at='2025-10-07T19:02:11.022615+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0a3b02-06a4-6783-801a-376c57251209'}}, tasks=(), interrupts=())

# %% [markdown]
# ### Persisting state
#
# Using database like Sqlite means state is persisted!
#
# For example, we can re-start the notebook kernel and see that we can still load from Sqlite DB on disk.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}
graph_state = graph.get_state(config)
graph_state
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content="hi! I'm Emmanuel", additional_kwargs={}, response_metadata={}, id='dbddbbf8-2ec7-4334-86f7-d3ee7cf83735'), AIMessage(content='Hello Emmanuel! Nice to meet you. How can I help you today? If you’d like to keep talking about the 49ers or anything else, just let me know!', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b-cloud', 'created_at': '2025-10-07T19:02:07.604773746Z', 'done': True, 'done_reason': 'stop', 'total_duration': 905316289, 'load_duration': None, 'prompt_eval_count': 392, 'prompt_eval_duration': None, 'eval_count': 123, 'eval_duration': None, 'model_name': 'gpt-oss:20b-cloud'}, id='run--3652cad5-f65f-43d3-90cc-505f10b6cb5b-0', usage_metadata={'input_tokens': 392, 'output_tokens': 123, 'total_tokens': 515}), HumanMessage(content="what's my name?", additional_kwargs={}, response_metadata={}, id='0dab5b81-c82c-4cc0-a1e9-7b962c5f093d'), AIMessage(content='You’re Emmanuel.', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b-cloud', 'created_at': '2025-10-07T19:02:10.195240624Z', 'done': True, 'done_reason': 'stop', 'total_duration': 846100970, 'load_duration': None, 'prompt_eval_count': 338, 'prompt_eval_duration': None, 'eval_count': 71, 'eval_duration': None, 'model_name': 'gpt-oss:20b-cloud'}, id='run--ef9aa052-c59d-4cf3-90d8-2bf7f08f29a1-0', usage_metadata={'input_tokens': 338, 'output_tokens': 71, 'total_tokens': 409}), HumanMessage(content='i like Chelsea Football Club!', additional_kwargs={}, response_metadata={}, id='0b8b7106-20b7-462c-99ce-e37d68a0e7ca'), AIMessage(content='That’s great! Chelsea has had some exciting seasons over the years. Do you have a favorite player or a particular match that stands out for you?', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b-cloud', 'created_at': '2025-10-07T19:02:11.032407832Z', 'done': True, 'done_reason': 'stop', 'total_duration': 641049720, 'load_duration': None, 'prompt_eval_count': 358, 'prompt_eval_duration': None, 'eval_count': 100, 'eval_duration': None, 'model_name': 'gpt-oss:20b-cloud'}, id='run--d9e25eb2-be71-4931-8725-fdebf0f9beec-0', usage_metadata={'input_tokens': 358, 'output_tokens': 100, 'total_tokens': 458})], 'summary': '**Extended Summary of the Conversation**\n\n1. **Initial Interaction**  \n   - The user first introduced themselves as **Lance** and expressed a fondness for the San\u202fFrancisco\u202f49ers.  \n   - The assistant acknowledged Lance’s name and offered to discuss various aspects of the 49ers (history, roster, memorable games, etc.).  \n   - Lance repeated his introduction, and the assistant reiterated his name and readiness to talk about the team.\n\n2. **Repetition and Briefness**  \n   - The conversation remained brief and somewhat repetitive, with Lance re‑introducing himself at the end without directly responding to the assistant’s prompts about the 49ers.\n\n3. **Name Change**  \n   - In a subsequent message, the user introduced themselves as **Emmanuel**.  \n   - The assistant greeted Emmanuel and asked how it could help, offering to continue discussing the 49ers or any other topic.\n\nThe conversation now reflects a change in the user’s name from Lance to Emmanuel, with the assistant acknowledging the new name and remaining open to further discussion.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0a3b02-0e96-6f96-801b-2b9cf3d0c538'}}, metadata={'source': 'loop', 'step': 27, 'parents': {}}, created_at='2025-10-07T19:02:11.022615+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0a3b02-06a4-6783-801a-376c57251209'}}, tasks=(), interrupts=())

# %% [markdown]
# ## LangGraph Studio
#
# **⚠️ DISCLAIMER**
#
# Since the filming of these videos, we've updated Studio so that it can be run locally and opened in your browser. This is now the preferred way to run Studio (rather than using the Desktop App as shown in the video). See documentation [here](https://langchain-ai.github.io/langgraph/concepts/langgraph_studio/#local-development-server) on the local development server and [here](https://langchain-ai.github.io/langgraph/how-tos/local-studio/#run-the-development-server). To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the Studio UI: `https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024`.
